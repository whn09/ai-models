# %%
# !pip install ai-models

# %%
# !pip install ai-models-panguweather
# !pip install ai-models-fourcastnet
# !pip install ai-models-graphcast  # Install details at https://github.com/ecmwf-lab/ai-models-graphcast
# !pip install ai-models-fourcastnetv2

# %%
# !wget https://developer.download.nvidia.com/compute/cudnn/9.5.1/local_installers/cudnn-local-repo-ubuntu2204-9.5.1_1.0-1_amd64.deb
# !sudo dpkg -i cudnn-local-repo-ubuntu2204-9.5.1_1.0-1_amd64.deb
# !sudo cp /var/cudnn-local-repo-ubuntu2204-9.5.1/cudnn-*-keyring.gpg /usr/share/keyrings/
# !sudo apt-get update
# !sudo apt-get -y install cudnn

# %%
# !ai-models --input cds --date 20220101 --time 0000 --download-assets --lead-time 360 panguweather
# Out:
# 2024-11-01 05:56:38,063 INFO Writing results to panguweather.grib
# 2024-11-01 05:56:38,063 INFO Loading pressure fields from CDS
# 2024-11-01 05:56:38,486 WARNING [2024-10-30T00:00:00] System is having technical problems on its adaptor for accessing external URLs. Some requests might randomnly fail. We are working to resume operations asap.
# 2024-11-01 05:56:38,486 WARNING [2024-10-30T00:00:00] System is having technical problems on its adaptor for accessing external URLs. Some requests might randomnly fail. We are working to resume operations asap.
# 2024-11-01 05:56:38,486 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-01 05:56:38,486 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-01 05:56:38,486 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-01 05:56:38,486 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-01 05:56:38,486 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-01 05:56:38,486 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-01 05:56:38,487 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# 2024-11-01 05:56:38,487 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# 2024-11-01 05:56:38,487 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2024-11-01 05:56:38,487 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2024-11-01 05:56:38,927 INFO Loading surface fields from CDS
# 2024-11-01 05:56:39,246 WARNING [2024-10-30T00:00:00] System is having technical problems on its adaptor for accessing external URLs. Some requests might randomnly fail. We are working to resume operations asap.
# 2024-11-01 05:56:39,246 WARNING [2024-10-30T00:00:00] System is having technical problems on its adaptor for accessing external URLs. Some requests might randomnly fail. We are working to resume operations asap.
# 2024-11-01 05:56:39,246 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-01 05:56:39,246 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-01 05:56:39,246 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-01 05:56:39,246 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-01 05:56:39,246 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-01 05:56:39,246 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-01 05:56:39,246 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# 2024-11-01 05:56:39,246 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# 2024-11-01 05:56:39,246 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2024-11-01 05:56:39,246 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2024-11-01 05:56:39,272 INFO Using device 'GPU'. The speed of inference depends greatly on the device.
# 2024-11-01 05:56:39,272 INFO ONNXRuntime providers: ['CUDAExecutionProvider', 'CPUExecutionProvider']
# 2024-11-01 05:57:03,634 INFO Loading ./pangu_weather_24.onnx: 24 seconds.
# 2024-11-01 05:57:25,539 INFO Loading ./pangu_weather_6.onnx: 21 seconds.
# 2024-11-01 05:57:25,580 INFO Starting date is 2022-01-01 00:00:00
# 2024-11-01 05:57:25,581 INFO Writing input fields
# 2024-11-01 05:57:26,482 INFO Writing step 0: 0.9 second.
# 2024-11-01 05:57:26,482 INFO Model initialisation: 48 seconds
# 2024-11-01 05:57:26,482 INFO Starting inference for 60 steps (360h).
# 2024-11-01 05:57:29,524 INFO Done 1 out of 60 in 3 seconds (6h), ETA: 3 minutes 2 seconds.
# 2024-11-01 05:57:32,003 INFO Done 2 out of 60 in 2 seconds (12h), ETA: 2 minutes 42 seconds.
# 2024-11-01 05:57:34,457 INFO Done 3 out of 60 in 2 seconds (18h), ETA: 2 minutes 34 seconds.
# 2024-11-01 05:57:37,125 INFO Done 4 out of 60 in 2 seconds (24h), ETA: 2 minutes 31 seconds.
# 2024-11-01 05:57:39,569 INFO Done 5 out of 60 in 2 seconds (30h), ETA: 2 minutes 26 seconds.
# 2024-11-01 05:57:42,009 INFO Done 6 out of 60 in 2 seconds (36h), ETA: 2 minutes 22 seconds.
# 2024-11-01 05:57:44,451 INFO Done 7 out of 60 in 2 seconds (42h), ETA: 2 minutes 18 seconds.
# 2024-11-01 05:57:46,900 INFO Done 8 out of 60 in 2 seconds (48h), ETA: 2 minutes 15 seconds.
# 2024-11-01 05:57:49,383 INFO Done 9 out of 60 in 2 seconds (54h), ETA: 2 minutes 12 seconds.
# 2024-11-01 05:57:51,824 INFO Done 10 out of 60 in 2 seconds (60h), ETA: 2 minutes 9 seconds.
# 2024-11-01 05:57:54,285 INFO Done 11 out of 60 in 2 seconds (66h), ETA: 2 minutes 6 seconds.
# 2024-11-01 05:57:56,763 INFO Done 12 out of 60 in 2 seconds (72h), ETA: 2 minutes 3 seconds.
# 2024-11-01 05:57:59,194 INFO Done 13 out of 60 in 2 seconds (78h), ETA: 2 minutes.
# 2024-11-01 05:58:01,635 INFO Done 14 out of 60 in 2 seconds (84h), ETA: 1 minute 58 seconds.
# 2024-11-01 05:58:04,087 INFO Done 15 out of 60 in 2 seconds (90h), ETA: 1 minute 55 seconds.
# 2024-11-01 05:58:06,549 INFO Done 16 out of 60 in 2 seconds (96h), ETA: 1 minute 52 seconds.
# 2024-11-01 05:58:09,007 INFO Done 17 out of 60 in 2 seconds (102h), ETA: 1 minute 50 seconds.
# 2024-11-01 05:58:11,464 INFO Done 18 out of 60 in 2 seconds (108h), ETA: 1 minute 47 seconds.
# 2024-11-01 05:58:13,917 INFO Done 19 out of 60 in 2 seconds (114h), ETA: 1 minute 44 seconds.
# 2024-11-01 05:58:16,386 INFO Done 20 out of 60 in 2 seconds (120h), ETA: 1 minute 42 seconds.
# 2024-11-01 05:58:18,814 INFO Done 21 out of 60 in 2 seconds (126h), ETA: 1 minute 39 seconds.
# 2024-11-01 05:58:21,245 INFO Done 22 out of 60 in 2 seconds (132h), ETA: 1 minute 37 seconds.
# 2024-11-01 05:58:23,676 INFO Done 23 out of 60 in 2 seconds (138h), ETA: 1 minute 34 seconds.
# 2024-11-01 05:58:26,163 INFO Done 24 out of 60 in 2 seconds (144h), ETA: 1 minute 32 seconds.
# 2024-11-01 05:58:28,613 INFO Done 25 out of 60 in 2 seconds (150h), ETA: 1 minute 29 seconds.
# 2024-11-01 05:58:31,065 INFO Done 26 out of 60 in 2 seconds (156h), ETA: 1 minute 26 seconds.
# 2024-11-01 05:58:33,511 INFO Done 27 out of 60 in 2 seconds (162h), ETA: 1 minute 24 seconds.
# 2024-11-01 05:58:35,960 INFO Done 28 out of 60 in 2 seconds (168h), ETA: 1 minute 21 seconds.
# 2024-11-01 05:58:38,434 INFO Done 29 out of 60 in 2 seconds (174h), ETA: 1 minute 19 seconds.
# 2024-11-01 05:58:40,904 INFO Done 30 out of 60 in 2 seconds (180h), ETA: 1 minute 16 seconds.
# 2024-11-01 05:58:43,378 INFO Done 31 out of 60 in 2 seconds (186h), ETA: 1 minute 14 seconds.
# 2024-11-01 05:58:45,874 INFO Done 32 out of 60 in 2 seconds (192h), ETA: 1 minute 11 seconds.
# 2024-11-01 05:58:48,346 INFO Done 33 out of 60 in 2 seconds (198h), ETA: 1 minute 9 seconds.
# 2024-11-01 05:58:50,796 INFO Done 34 out of 60 in 2 seconds (204h), ETA: 1 minute 6 seconds.
# 2024-11-01 05:58:53,258 INFO Done 35 out of 60 in 2 seconds (210h), ETA: 1 minute 4 seconds.
# 2024-11-01 05:58:55,761 INFO Done 36 out of 60 in 2 seconds (216h), ETA: 1 minute 1 second.
# 2024-11-01 05:58:58,190 INFO Done 37 out of 60 in 2 seconds (222h), ETA: 59 seconds.
# 2024-11-01 05:59:00,672 INFO Done 38 out of 60 in 2 seconds (228h), ETA: 57 seconds.
# 2024-11-01 05:59:03,135 INFO Done 39 out of 60 in 2 seconds (234h), ETA: 54 seconds.
# 2024-11-01 05:59:05,584 INFO Done 40 out of 60 in 2 seconds (240h), ETA: 52 seconds.
# 2024-11-01 05:59:08,025 INFO Done 41 out of 60 in 2 seconds (246h), ETA: 49 seconds.
# 2024-11-01 05:59:10,518 INFO Done 42 out of 60 in 2 seconds (252h), ETA: 47 seconds.
# 2024-11-01 05:59:12,952 INFO Done 43 out of 60 in 2 seconds (258h), ETA: 44 seconds.
# 2024-11-01 05:59:15,422 INFO Done 44 out of 60 in 2 seconds (264h), ETA: 42 seconds.
# 2024-11-01 05:59:17,907 INFO Done 45 out of 60 in 2 seconds (270h), ETA: 39 seconds.
# 2024-11-01 05:59:20,359 INFO Done 46 out of 60 in 2 seconds (276h), ETA: 37 seconds.
# 2024-11-01 05:59:22,841 INFO Done 47 out of 60 in 2 seconds (282h), ETA: 34 seconds.
# 2024-11-01 05:59:25,330 INFO Done 48 out of 60 in 2 seconds (288h), ETA: 32 seconds.
# 2024-11-01 05:59:27,767 INFO Done 49 out of 60 in 2 seconds (294h), ETA: 29 seconds.
# 2024-11-01 05:59:30,239 INFO Done 50 out of 60 in 2 seconds (300h), ETA: 27 seconds.
# 2024-11-01 05:59:32,692 INFO Done 51 out of 60 in 2 seconds (306h), ETA: 24 seconds.
# 2024-11-01 05:59:35,137 INFO Done 52 out of 60 in 2 seconds (312h), ETA: 22 seconds.
# 2024-11-01 05:59:37,589 INFO Done 53 out of 60 in 2 seconds (318h), ETA: 19 seconds.
# 2024-11-01 05:59:40,024 INFO Done 54 out of 60 in 2 seconds (324h), ETA: 17 seconds.
# 2024-11-01 05:59:42,505 INFO Done 55 out of 60 in 2 seconds (330h), ETA: 14 seconds.
# 2024-11-01 05:59:45,001 INFO Done 56 out of 60 in 2 seconds (336h), ETA: 12 seconds.
# 2024-11-01 05:59:47,466 INFO Done 57 out of 60 in 2 seconds (342h), ETA: 9 seconds.
# 2024-11-01 05:59:49,923 INFO Done 58 out of 60 in 2 seconds (348h), ETA: 7 seconds.
# 2024-11-01 05:59:52,403 INFO Done 59 out of 60 in 2 seconds (354h), ETA: 4 seconds.
# 2024-11-01 05:59:54,887 INFO Done 60 out of 60 in 2 seconds (360h), ETA: 2 seconds.
# 2024-11-01 05:59:54,887 INFO Elapsed: 2 minutes 28 seconds.
# 2024-11-01 05:59:54,887 INFO Average: 2 seconds per step.
# 2024-11-01 05:59:55,025 INFO Total time: 3 minutes 17 seconds.

# %%
# !ai-models --input cds --date 20220101 --time 0000 --download-assets --lead-time 360 graphcast

# %%
# !ai-models --input cds --date 20220101 --time 0000 --download-assets --lead-time 360 fourcastnet

# %%
# !ai-models --input cds --date 20220101 --time 0000 --download-assets --lead-time 360 fourcastnetv2-small
# Out:
# 2024-11-01 06:15:03,732 INFO Writing results to fourcastnetv2-small.grib
# 2024-11-01 06:15:03,733 INFO Downloading /home/ubuntu/ai-models/global_means.npy
# 2024-11-01 06:15:03,733 INFO Downloading https://get.ecmwf.int/repository/test-data/ai-models/fourcastnetv2/small/global_means.npy
# 2024-11-01 06:15:04,540 INFO Downloading /home/ubuntu/ai-models/global_stds.npy
# 2024-11-01 06:15:04,540 INFO Downloading https://get.ecmwf.int/repository/test-data/ai-models/fourcastnetv2/small/global_stds.npy
# 2024-11-01 06:15:05,227 INFO Loading ./global_means.npy
# 2024-11-01 06:15:05,227 INFO Loading ./global_stds.npy
# 2024-11-01 06:15:05,228 INFO Loading surface fields from CDS
# 2024-11-01 06:15:05,614 WARNING [2024-10-30T00:00:00] System is having technical problems on its adaptor for accessing external URLs. Some requests might randomnly fail. We are working to resume operations asap.
# 2024-11-01 06:15:05,614 WARNING [2024-10-30T00:00:00] System is having technical problems on its adaptor for accessing external URLs. Some requests might randomnly fail. We are working to resume operations asap.
# 2024-11-01 06:15:05,614 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-01 06:15:05,614 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-01 06:15:05,614 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-01 06:15:05,614 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-01 06:15:05,614 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-01 06:15:05,614 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-01 06:15:05,614 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# 2024-11-01 06:15:05,614 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# 2024-11-01 06:15:05,614 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2024-11-01 06:15:05,614 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2024-11-01 06:15:05,705 INFO Loading pressure fields from CDS
# 2024-11-01 06:15:06,036 WARNING [2024-10-30T00:00:00] System is having technical problems on its adaptor for accessing external URLs. Some requests might randomnly fail. We are working to resume operations asap.
# 2024-11-01 06:15:06,036 WARNING [2024-10-30T00:00:00] System is having technical problems on its adaptor for accessing external URLs. Some requests might randomnly fail. We are working to resume operations asap.
# 2024-11-01 06:15:06,037 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-01 06:15:06,037 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-01 06:15:06,037 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-01 06:15:06,037 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-01 06:15:06,037 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-01 06:15:06,037 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-01 06:15:06,037 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# 2024-11-01 06:15:06,037 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# 2024-11-01 06:15:06,037 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2024-11-01 06:15:06,037 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2024-11-01 06:15:08,883 INFO Using device 'CUDA'. The speed of inference depends greatly on the device.
# /opt/conda/envs/pytorch/lib/python3.11/site-packages/ai_models_fourcastnetv2/model.py:146: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_file, map_location=self.device)
# 2024-11-01 06:15:11,825 INFO Starting date is 2022-01-01 00:00:00
# 2024-11-01 06:15:11,825 INFO Writing input fields
# 2024-11-01 06:15:12,669 INFO Writing step 0: 0.8 second.
# 2024-11-01 06:15:12,669 INFO Model initialisation: 7 seconds
# 2024-11-01 06:15:12,669 INFO Starting inference for 60 steps (360h).
# /opt/conda/envs/pytorch/lib/python3.11/site-packages/ai_models_fourcastnetv2/fourcastnetv2/layers.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=False):
# /opt/conda/envs/pytorch/lib/python3.11/site-packages/ai_models_fourcastnetv2/fourcastnetv2/layers.py:632: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=False):
# 2024-11-01 06:15:14,503 INFO Done 1 out of 60 in 1 second (6h), ETA: 1 minute 50 seconds.
# 2024-11-01 06:15:16,006 INFO Done 2 out of 60 in 1 second (12h), ETA: 1 minute 38 seconds.
# 2024-11-01 06:15:17,457 INFO Done 3 out of 60 in 1 second (18h), ETA: 1 minute 32 seconds.
# 2024-11-01 06:15:18,955 INFO Done 4 out of 60 in 1 second (24h), ETA: 1 minute 29 seconds.
# 2024-11-01 06:15:20,411 INFO Done 5 out of 60 in 1 second (30h), ETA: 1 minute 26 seconds.
# 2024-11-01 06:15:21,882 INFO Done 6 out of 60 in 1 second (36h), ETA: 1 minute 24 seconds.
# 2024-11-01 06:15:23,363 INFO Done 7 out of 60 in 1 second (42h), ETA: 1 minute 22 seconds.
# 2024-11-01 06:15:24,829 INFO Done 8 out of 60 in 1 second (48h), ETA: 1 minute 20 seconds.
# 2024-11-01 06:15:26,292 INFO Done 9 out of 60 in 1 second (54h), ETA: 1 minute 18 seconds.
# 2024-11-01 06:15:27,740 INFO Done 10 out of 60 in 1 second (60h), ETA: 1 minute 16 seconds.
# 2024-11-01 06:15:29,219 INFO Done 11 out of 60 in 1 second (66h), ETA: 1 minute 15 seconds.
# 2024-11-01 06:15:30,727 INFO Done 12 out of 60 in 1 second (72h), ETA: 1 minute 13 seconds.
# 2024-11-01 06:15:32,183 INFO Done 13 out of 60 in 1 second (78h), ETA: 1 minute 12 seconds.
# 2024-11-01 06:15:33,706 INFO Done 14 out of 60 in 1 second (84h), ETA: 1 minute 10 seconds.
# 2024-11-01 06:15:35,169 INFO Done 15 out of 60 in 1 second (90h), ETA: 1 minute 9 seconds.
# 2024-11-01 06:15:36,650 INFO Done 16 out of 60 in 1 second (96h), ETA: 1 minute 7 seconds.
# 2024-11-01 06:15:38,113 INFO Done 17 out of 60 in 1 second (102h), ETA: 1 minute 5 seconds.
# 2024-11-01 06:15:39,567 INFO Done 18 out of 60 in 1 second (108h), ETA: 1 minute 4 seconds.
# 2024-11-01 06:15:41,024 INFO Done 19 out of 60 in 1 second (114h), ETA: 1 minute 2 seconds.
# 2024-11-01 06:15:42,507 INFO Done 20 out of 60 in 1 second (120h), ETA: 1 minute 1 second.
# 2024-11-01 06:15:43,980 INFO Done 21 out of 60 in 1 second (126h), ETA: 59 seconds.
# 2024-11-01 06:15:45,453 INFO Done 22 out of 60 in 1 second (132h), ETA: 58 seconds.
# 2024-11-01 06:15:46,950 INFO Done 23 out of 60 in 1 second (138h), ETA: 56 seconds.
# 2024-11-01 06:15:48,468 INFO Done 24 out of 60 in 1 second (144h), ETA: 55 seconds.
# 2024-11-01 06:15:50,004 INFO Done 25 out of 60 in 1 second (150h), ETA: 53 seconds.
# 2024-11-01 06:15:51,476 INFO Done 26 out of 60 in 1 second (156h), ETA: 52 seconds.
# 2024-11-01 06:15:52,995 INFO Done 27 out of 60 in 1 second (162h), ETA: 50 seconds.
# 2024-11-01 06:15:54,458 INFO Done 28 out of 60 in 1 second (168h), ETA: 49 seconds.
# 2024-11-01 06:15:55,951 INFO Done 29 out of 60 in 1 second (174h), ETA: 47 seconds.
# 2024-11-01 06:15:57,423 INFO Done 30 out of 60 in 1 second (180h), ETA: 46 seconds.
# 2024-11-01 06:15:58,876 INFO Done 31 out of 60 in 1 second (186h), ETA: 44 seconds.
# 2024-11-01 06:16:00,345 INFO Done 32 out of 60 in 1 second (192h), ETA: 43 seconds.
# 2024-11-01 06:16:01,869 INFO Done 33 out of 60 in 1 second (198h), ETA: 41 seconds.
# 2024-11-01 06:16:03,348 INFO Done 34 out of 60 in 1 second (204h), ETA: 40 seconds.
# 2024-11-01 06:16:04,841 INFO Done 35 out of 60 in 1 second (210h), ETA: 38 seconds.
# 2024-11-01 06:16:06,344 INFO Done 36 out of 60 in 1 second (216h), ETA: 37 seconds.
# 2024-11-01 06:16:07,834 INFO Done 37 out of 60 in 1 second (222h), ETA: 35 seconds.
# 2024-11-01 06:16:09,315 INFO Done 38 out of 60 in 1 second (228h), ETA: 34 seconds.
# 2024-11-01 06:16:10,778 INFO Done 39 out of 60 in 1 second (234h), ETA: 32 seconds.
# 2024-11-01 06:16:12,256 INFO Done 40 out of 60 in 1 second (240h), ETA: 31 seconds.
# 2024-11-01 06:16:13,709 INFO Done 41 out of 60 in 1 second (246h), ETA: 29 seconds.
# 2024-11-01 06:16:15,189 INFO Done 42 out of 60 in 1 second (252h), ETA: 28 seconds.
# 2024-11-01 06:16:16,684 INFO Done 43 out of 60 in 1 second (258h), ETA: 26 seconds.
# 2024-11-01 06:16:18,204 INFO Done 44 out of 60 in 1 second (264h), ETA: 25 seconds.
# 2024-11-01 06:16:19,696 INFO Done 45 out of 60 in 1 second (270h), ETA: 23 seconds.
# 2024-11-01 06:16:21,194 INFO Done 46 out of 60 in 1 second (276h), ETA: 22 seconds.
# 2024-11-01 06:16:22,669 INFO Done 47 out of 60 in 1 second (282h), ETA: 20 seconds.
# 2024-11-01 06:16:24,190 INFO Done 48 out of 60 in 1 second (288h), ETA: 19 seconds.
# 2024-11-01 06:16:25,651 INFO Done 49 out of 60 in 1 second (294h), ETA: 17 seconds.
# 2024-11-01 06:16:27,163 INFO Done 50 out of 60 in 1 second (300h), ETA: 16 seconds.
# 2024-11-01 06:16:28,658 INFO Done 51 out of 60 in 1 second (306h), ETA: 14 seconds.
# 2024-11-01 06:16:30,160 INFO Done 52 out of 60 in 1 second (312h), ETA: 13 seconds.
# 2024-11-01 06:16:31,647 INFO Done 53 out of 60 in 1 second (318h), ETA: 11 seconds.
# 2024-11-01 06:16:33,112 INFO Done 54 out of 60 in 1 second (324h), ETA: 10 seconds.
# 2024-11-01 06:16:34,611 INFO Done 55 out of 60 in 1 second (330h), ETA: 8 seconds.
# 2024-11-01 06:16:36,095 INFO Done 56 out of 60 in 1 second (336h), ETA: 7 seconds.
# 2024-11-01 06:16:37,557 INFO Done 57 out of 60 in 1 second (342h), ETA: 5 seconds.
# 2024-11-01 06:16:39,053 INFO Done 58 out of 60 in 1 second (348h), ETA: 4 seconds.
# 2024-11-01 06:16:40,536 INFO Done 59 out of 60 in 1 second (354h), ETA: 2 seconds.
# 2024-11-01 06:16:42,068 INFO Done 60 out of 60 in 1 second (360h), ETA: 1 second.
# 2024-11-01 06:16:42,069 INFO Elapsed: 1 minute 29 seconds.
# 2024-11-01 06:16:42,069 INFO Average: 1 second per step.
# 2024-11-01 06:16:42,071 INFO Total time: 1 minute 39 seconds.
